# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
db = pd.read_csv('FIFA-21 Complete.csv', delimiter=";")

db = db.sort_values(['player_id'])
db.head()
# Out:
#       player_id                  name  nationality   position  overall  age  \
# 310          41               Iniesta        Spain  LM|CM|CAM       82   36
# 1271         80        Emre Belözoglu       Turkey     CDM|CM       77   39
# 4174        768                Felipe       Brazil         CB       72   35
# 222        1179      Gianluigi Buffon        Italy         GK       83   42
# 4173       2147  Maarten Stekelenburg  Netherlands         GK       72   37
#
#       hits  potential            team
# 310     57         82    Vissel Kobe
# 1271     6         77  Fenerbahçe SK
# 4174     0         72           SPAL
# 222     50         83       Juventus
# 4173     2         72        Everton

# %%
db.dtypes
# Out:
# player_id       int64
# name           object
# nationality    object
# position       object
# overall         int64
# age             int64
# hits            int64
# potential       int64
# team           object
# dtype: object

# %%
db = db.set_index('player_id')

# %%
db[::-1]
# Out:
#                            name  nationality   position  overall  age  hits  \
# player_id
# 256469       Juan Camilo Suárez     Colombia         CB       56   21     0
# 256467               Joan Parra     Colombia         GK       59   20     0
# 256460     Tim Luis Maciejewski      Germany  LM|CAM|RW       64   19     0
# 256445                   Ruvira        Spain         GK       56   20     0
# 256444        Luciano Arriagada        Chile         ST       57   18     0
# ...                         ...          ...        ...      ...  ...   ...
# 2147       Maarten Stekelenburg  Netherlands         GK       72   37     2
# 1179           Gianluigi Buffon        Italy         GK       83   42    50
# 768                      Felipe       Brazil         CB       72   35     0
# 80               Emre Belözoglu       Turkey     CDM|CM       77   39     6
# 41                      Iniesta        Spain  LM|CM|CAM       82   36    57
#
#            potential                 team
# player_id
# 256469            63         Envigado FC
# 256467            71         Envigado FC
# 256460            79  1. FC Union Berlin
# 256445            70      CF Fuenlabrada
# 256444            73           Colo-Colo
# ...              ...                  ...
# 2147              72             Everton
# 1179              83            Juventus
# 768               72                SPAL
# 80                77       Fenerbahçe SK
# 41                82         Vissel Kobe
#
# [17981 rows x 8 columns]

# %%
print(db.iloc[0].team)
print(db.iloc[0].team[:-1])
# Out:
# Vissel Kobe
# Vissel Kobe

# %%
db.team = db.team.str.rstrip()
db
# Out:
#                            name  nationality   position  overall  age  hits  \
# player_id
# 41                      Iniesta        Spain  LM|CM|CAM       82   36    57
# 80               Emre Belözoglu       Turkey     CDM|CM       77   39     6
# 768                      Felipe       Brazil         CB       72   35     0
# 1179           Gianluigi Buffon        Italy         GK       83   42    50
# 2147       Maarten Stekelenburg  Netherlands         GK       72   37     2
# ...                         ...          ...        ...      ...  ...   ...
# 256444        Luciano Arriagada        Chile         ST       57   18     0
# 256445                   Ruvira        Spain         GK       56   20     0
# 256460     Tim Luis Maciejewski      Germany  LM|CAM|RW       64   19     0
# 256467               Joan Parra     Colombia         GK       59   20     0
# 256469       Juan Camilo Suárez     Colombia         CB       56   21     0
#
#            potential                team
# player_id
# 41                82         Vissel Kobe
# 80                77       Fenerbahçe SK
# 768               72                SPAL
# 1179              83            Juventus
# 2147              72             Everton
# ...              ...                 ...
# 256444            73           Colo-Colo
# 256445            70      CF Fuenlabrada
# 256460            79  1. FC Union Berlin
# 256467            71         Envigado FC
# 256469            63         Envigado FC
#
# [17981 rows x 8 columns]

# %%
engine = create_engine('postgresql://soundarzozm:chittorababy@localhost:5432/fifa21')
db.to_sql('data', engine)
# Out:
# 981
